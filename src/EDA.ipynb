# %% [markdown]
# In this module, we extract some insights on common subjects and their examination characteristics, based on past examination data.

# %%
import Qlassifier as Q

# %%
# Set the scope: popular VCE subjects with large exam component
subjects = [
    "specialist_mathematics",
    "mathematical_methods",
    "physics",
    "chemistry",
    "business_management", 
]

years = range(2012, 2024) # Set timeframe

# %%
for subject in subjects: 
    Q.material_collector.extract_exams(subject, years)
# Out:
# Unable to find subject specialist_mathematics. Make sure it is spelt correctly.
# Unable to find subject mathematical_methods. Make sure it is spelt correctly.
# Unable to find an exam for physics over the years range(2012, 2024)
# Unable to find an exam for chemistry over the years range(2012, 2024)
# Unable to find subject business_management. Make sure it is spelt correctly.
