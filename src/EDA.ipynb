# %% [markdown]
# In this module, we extract some insights on common subjects and their examination characteristics, based on past examination data.

# %%
from Qlassifier import api
# Out:
# Traceback (most recent call last):
#
#   File ~/projects/Qlassifier/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3699 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from Qlassifier import api
#
#   File ~/projects/Qlassifier/src/Qlassifier/api.py:45
#     def process_sds(subjects: list[str])
#                                         ^
# SyntaxError: expected ':'

# %%
# Set the scope: popular VCE subjects with large exam component
subjects = [
    "specialist_mathematics",
    "mathematical_methods",
    "physics",
    "chemistry",
    "business_management", 
]

years = range(2012, 2024) # Set timeframe

all_exams = api.process_exams(subjects, years)
assert(all_exams)
# Out:
# ======= specialist_mathematics =======
# Downloading exams...
# Success!
# Processing exams...
# Success!
# ======= mathematical_methods =======
# Downloading exams...
# Success!
# Processing exams...
# Success!
# ======= physics =======
# Downloading exams...
# Success!
# Processing exams...
# Success!
# ======= chemistry =======
# Downloading exams...
# Success!
# Processing exams...
# Success!
# ======= business_management =======
# Downloading exams...
# Success!
# Processing exams...
# Success!
